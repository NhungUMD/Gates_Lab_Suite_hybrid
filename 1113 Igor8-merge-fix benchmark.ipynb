# %%
from Core_Definition import *
import numpy as np
import os
from Visualization import *
from Auto_Algorithm import *
import csv
import matplotlib.pyplot as plt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20231113"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_12short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))

datapaf="data/2023-11-13 UMD__1-site-benchmarking-12/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]
print (file_list)
listind=[11]
print(listind[0])
i=listind[0]
S=Quantum_Circuit(nqubit,"SCHW")
Set_Mapping(ind)
S.Interpret_GatesLab_Sequence(sequence[listind[0]])
state_sim=S.Simulate()
simresults[i]=state_sim.population
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
# for i in listind:
state_list=[]
for i in range(len(file_list)):
    print(file_list[i])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[listind[0]])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[i],keep_file=True)
    state_list.append(state_m1)
    measresults[i]=state_m1.population

Display_States_Population(states=[state_sim,state_list[0],state_list[1]],label=["sim","2023 nov 13 block","2023 nov 13 explicit"],plot_size=(20,8))
# Out:
# ['2023-11-13-161940_Line_001.txt', '2023-11-13-162059_Line_002.txt']
# 11
# 2023-11-13-161940_Line_001.txt
# 2023-11-13-162059_Line_002.txt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20230911"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_12short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))

datapaf="data/2023-09-11 test__1-spatial_site_N=20_correctblock12/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]
print (file_list)
listind=[18,19,20,11,1]
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
# for i in listind:
for i in range(len(file_list)):
    print(listind[i])
#     print(sequence[i])
    print(file_list[i])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[listind[i]])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[i],keep_file=True)
    measresults[i]=state_m1.population

    Display_States_Population(states=[state_sim,state_m1],label=["sim","exp 2023 sep 11"],plot_size=(20,8))
# Out:
# ['2023-09-11-142328_Line_019.txt', '2023-09-11-142607_Line_020.txt', '2023-09-11-142851_Line_021.txt', '2023-09-11-143103_Line_012.txt', '2023-09-11-143132_Line_002.txt']
# 18
# 2023-09-11-142328_Line_019.txt
# 19
# 2023-09-11-142607_Line_020.txt
# 20
# 2023-09-11-142851_Line_021.txt
# 11
# 2023-09-11-143103_Line_012.txt
# 1
# 2023-09-11-143132_Line_002.txt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20230911"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_12short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))

datapaf="data/2022-09-28 pitime__1-site_dt0p5_compare/"
datapaf2="data/2022-10-19 pitime__1-site_dt0p5_compare/"
datapaf3="data/2023-09-11 test__1-site_dt0p5_compare/"
datapaf4="data/2023-11-13 UMD__1-site-benchmarking-12/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]
file_list2=[f for f in os.listdir(datapaf2) if f.find(".txt")>-1]
file_list3=[f for f in os.listdir(datapaf3) if f.find(".txt")>-1]
file_list4=[f for f in os.listdir(datapaf4) if f.find(".txt")>-1]
print (file_list)
listind=[11]
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
for i in listind:
    print(i)
#     print(sequence[i])
    print(file_list[0])
    print(file_list2[0])
    print(file_list3[0])
    print(file_list4[1])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[i])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    state_m2=Quantum_State(nqubit)
    state_m3=Quantum_State(nqubit)
    state_m4=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[0],keep_file=True)
    state_m2.Import(datapaf2+file_list2[0],keep_file=True)
    state_m3.Import(datapaf3+file_list3[0],keep_file=True)
    state_m4.Import(datapaf4+file_list4[1],keep_file=True)
    measresults[i]=state_m1.population

    Display_States_Population(states=[state_sim,state_m1,state_m2,state_m3,state_m4],label=["sim","exp 2022 sep 28","exp 2022 oct 19","exp 2023 sep 11","exp 2023 nov 13"],plot_size=(20,8))
# Out:
# ['2022-09-28-163959_Line_022.txt']
# 11
# 2022-09-28-163959_Line_022.txt
# 2022-10-19-183127_Line_022.txt
# 2023-09-11-143407_Line_022.txt
# 2023-11-13-162059_Line_002.txt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20230316"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_13short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))
datapaf="data/2023-03-16 test__1-site_dt0p5_compare13/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]

listind=[11]
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
for i in listind:
    print(i)
#     print(sequence[i])
    print(file_list[0])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[i])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    state_m2=Quantum_State(nqubit)
    state_m3=Quantum_State(nqubit)
    state_m4=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[0],keep_file=True)
    measresults[i]=state_m1.population

    Display_States_Population(states=[state_sim,state_m1],label=["sim XX13","exp XX13 mar 16"],plot_size=(20,8))
# Out:
# 11
# 2023-03-16-174100_Line_022.txt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20230316"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_12short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))
datapaf="data/2022-10-19 pitime__1-site_dt0p5_compare/"
datapaf2="data/2022-09-28 pitime__1-site_dt0p5_compare/"
datapaf3="data/2023-03-16 test__1-site_dt0p5_compare/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]
file_list2=[f for f in os.listdir(datapaf2) if f.find(".txt")>-1]
file_list3=[f for f in os.listdir(datapaf3) if f.find(".txt")>-1]
print (file_list)
listind=[11]
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
for i in listind:
    print(i)
#     print(sequence[i])
    print(file_list[0])
    print(file_list2[0])
    print(file_list3[0])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[i])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    state_m2=Quantum_State(nqubit)
    state_m3=Quantum_State(nqubit)
    state_m4=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[0],keep_file=True)
    state_m2.Import(datapaf2+file_list2[0],keep_file=True)
    state_m3.Import(datapaf3+file_list3[0],keep_file=True)
#     state_m4.Import(datapaf2+file_list2[2],keep_file=True)
    measresults[i]=state_m1.population

    Display_States_Population(states=[state_sim,state_m2,state_m1,state_m3],label=["sim","exp sept 28","exp oct 19","exp mar 16"],plot_size=(20,8))
# Out:
# ['2022-10-19-183127_Line_022.txt', '2022-10-19-184635_Line_022.txt']
# 11
# 2022-10-19-183127_Line_022.txt
# 2022-09-28-163959_Line_022.txt
# 2023-03-16-171703_Line_022.txt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20230314"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_12short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))
datapaf="data/2022-10-19 pitime__1-site_dt0p5_compare/"
datapaf2="data/2023-03-14 test__1-site_dt0p5_compare/"
datapaf3="data/2023-03-16 test__1-site_dt0p5_compare/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]
file_list2=[f for f in os.listdir(datapaf2) if f.find(".txt")>-1]
file_list3=[f for f in os.listdir(datapaf3) if f.find(".txt")>-1]

listind=[11]
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
for i in listind:
    print(i)
#     print(sequence[i])
    print(file_list[0])
    print(file_list2[0])
    print(file_list2[1])
    print(file_list2[2])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[i])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    state_m2=Quantum_State(nqubit)
    state_m3=Quantum_State(nqubit)
    state_m4=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[0],keep_file=True)
    state_m2.Import(datapaf2+file_list2[0],keep_file=True)
    state_m3.Import(datapaf2+file_list2[0],keep_file=True)
    state_m4.Import(datapaf2+file_list2[2],keep_file=True)
    measresults[i]=state_m1.population

    Display_States_Population(states=[state_sim,state_m1,state_m2,state_m2],label=["sim","exp oct 19","exp mar 14","exp mar 14"],plot_size=(20,8))
# Out:
# 11
# 2022-10-19-183127_Line_022.txt
# 2023-03-14-165905_Line_022.txt
# 2023-03-14-170058_Line_022.txt
# 2023-03-14-170328_Line_022.txt

# %%
## N=20
nqubit=3
nsite=1
ind=[1,2,3]
date="20230316"
# paf ="Y:/Users/Nhung/2019/schwinger model/two-spatial site/"
# file_name="measured_"+str(date)+"_2-spatialsite_N="+str(N)+"_3214.csv"
# write_file=open(paf+file_name,'w')

sequence=open('schw_1site/1-spatial_site_N=20_12short.txt','r').read().splitlines()
j=0
simresults = np.zeros((len(sequence),2**(nqubit)))
measresults = np.zeros((len(sequence),2**(nqubit)))
datapaf="data/2022-10-19 pitime__1-site_dt0p5_compare/"
datapaf2="data/2023-03-14 test__1-site_dt0p5_compare/"
datapaf3="data/2023-03-16 test__1-site_dt0p5_compare/"

file_list=[f for f in os.listdir(datapaf) if f.find(".txt")>-1]
file_list2=[f for f in os.listdir(datapaf2) if f.find(".txt")>-1]
file_list3=[f for f in os.listdir(datapaf3) if f.find(".txt")>-1]

listind=[11]
# listind=[f-1 for f in listind]
# listind=range(len(sequence))
for i in listind:
    print(i)
#     print(sequence[i])
    print(file_list[0])
    print(file_list2[0])
    print(file_list3[0])
    S=Quantum_Circuit(nqubit,"SCHW")
    Set_Mapping(ind)
    S.Interpret_GatesLab_Sequence(sequence[i])
    state_sim=S.Simulate()
    simresults[i]=state_sim.population
#     simresults[i]=Trace_Out(state_sim,ind2).population
    state_m1=Quantum_State(nqubit)
    state_m2=Quantum_State(nqubit)
    state_m3=Quantum_State(nqubit)
    state_m4=Quantum_State(nqubit)
    Set_Mapping([1,2,3])
    state_m1.Import(datapaf+file_list[0],keep_file=True)
    state_m2.Import(datapaf2+file_list2[0],keep_file=True)
    state_m3.Import(datapaf3+file_list3[0],keep_file=True)
#     state_m4.Import(datapaf2+file_list2[2],keep_file=True)
    measresults[i]=state_m1.population

    Display_States_Population(states=[state_sim,state_m1,state_m2,state_m3],label=["sim","exp oct 19","exp mar 14","exp mar 16"],plot_size=(20,8))
